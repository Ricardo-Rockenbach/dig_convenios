# %%
import pandas as pd
import numpy as np
# Ler o arquivo bruto dos convenios

# Ler o arquivo xlsx
df = pd.read_excel(
    r"data\dados_brutos.xlsx",
    usecols=["CONVENIO","VALOR_CUSTO_M","VALOR_VENDA_M","VALOR_CUSTO_D","VALOR_VENDA_D","VALOR_CUSTO_T","VALOR_VENDA_T", "INDATA_INICIAL"],
    )
# extrair o mes da coluna "INDATA_INICIAL"
df["INDATA_INICIAL"] = pd.to_datetime(df["INDATA_INICIAL"], errors="coerce", dayfirst=True)
df["MES"] = df["INDATA_INICIAL"].dt.month

# remover linhas com valores nulos
df = df.dropna()
# definir index como a coluna "CONVENIO"
df = df.set_index("CONVENIO")
# Remover os covenios com nome "CONVENIO"
df = df[~df.index.str.contains("CONVENIO", case=False)]

display(df.info())
# Out:
# <class 'pandas.DataFrame'>
# Index: 89 entries, ACORDO to UNIMED
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   VALOR_CUSTO_M   89 non-null     object
#  1   VALOR_VENDA_M   89 non-null     object
#  2   VALOR_CUSTO_D   89 non-null     object
#  3   VALOR_VENDA_D   89 non-null     object
#  4   VALOR_CUSTO_T   89 non-null     object
#  5   VALOR_VENDA_T   89 non-null     object
#  6   INDATA_INICIAL  89 non-null     datetime64[us]
#  7   MES             89 non-null     float64
# dtypes: datetime64[us](1), float64(1), object(6)
# memory usage: 6.3+ KB
# None
