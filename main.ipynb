# %%
import pandas as pd
#import numpy as np
# Ler o arquivo bruto dos convenios

# Ler o arquivo xlsx
df = pd.read_excel(
    r"data\dados_brutos.xlsx",
    usecols=["CONVENIO","VALOR_CUSTO_M","VALOR_VENDA_M","VALOR_CUSTO_D","VALOR_VENDA_D","VALOR_CUSTO_T","VALOR_VENDA_T", "INDATA_INICIAL"],
    )
# extrair o mes da coluna "INDATA_INICIAL"
df["INDATA_INICIAL"] = pd.to_datetime(df["INDATA_INICIAL"], errors="coerce", dayfirst=True)
df["MES"] = df["INDATA_INICIAL"].dt.month

# remover linhas com valores nulos
df = df.dropna()
# definir index como a coluna "CONVENIO"
df = df.set_index("CONVENIO")
# Remover os covenios com nome "CONVENIO"
df = df[~df.index.str.contains("CONVENIO", case=False)]

display(df)
# Out:
#                         VALOR_CUSTO_M VALOR_VENDA_M VALOR_CUSTO_D  \
# CONVENIO
# ACORDO                        11696.8      62853.52      13973.75
# ACORDO JUDICIAL              15775.74      76043.96         13590
# C.M.I                         2591.63      16234.24       5030.55
# CABERGS                        228.03       3278.68       3912.65
# CAIXA ECONOMICA FEDERAL         23.74        331.11        573.45
# ...                               ...           ...           ...
# SAUDE MAIOR                  36139.77     359380.73     164420.65
# SOCIOS                        5273.09      17724.74      34980.45
# SULAMERICA                   10947.48      59866.26       17425.9
# SUS                          11413.24       69598.2       13266.3
# UNIMED                      557353.59      96910.72     287491.93
#
#                         VALOR_VENDA_D VALOR_CUSTO_T VALOR_VENDA_T  \
# CONVENIO
# ACORDO                          10300      48166.66     111109.91
# ACORDO JUDICIAL                 21500      16128.63      99410.31
# C.M.I                            7830      13694.47      25615.68
# CABERGS                       2190.13        887.92       1165.13
# CAIXA ECONOMICA FEDERAL        373.45             0             0
# ...                               ...           ...           ...
# SAUDE MAIOR                  63954.85      69709.98      23774.92
# SOCIOS                        20239.8       1416.67        730.92
# SULAMERICA                    9505.82      22366.41       5752.43
# SUS                              3950      18488.37      14129.98
# UNIMED                      282459.66      37252.62      66852.63
#
#                         INDATA_INICIAL  MES
# CONVENIO
# ACORDO                      2025-01-01  1.0
# ACORDO JUDICIAL             2025-01-01  1.0
# C.M.I                       2025-01-01  1.0
# CABERGS                     2025-01-01  1.0
# CAIXA ECONOMICA FEDERAL     2025-01-01  1.0
# ...                                ...  ...
# SAUDE MAIOR                 2025-06-01  6.0
# SOCIOS                      2025-06-01  6.0
# SULAMERICA                  2025-06-01  6.0
# SUS                         2025-06-01  6.0
# UNIMED                      2025-06-01  6.0
#
# [89 rows x 8 columns]
